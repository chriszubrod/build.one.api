# %%
import pyodbc

# %%
import requests

# %%
import json

# %%
def open_db_cnxn():
    """
    Opens a database connection.
    """
    database = pyodbc.connect(
        'DRIVER={ODBC Driver 17 for SQL Server};' +
        'SERVER=tcp:bchristopher.database.windows.net,1433;' +
        'DATABASE=buildone;' +
        'UID=zubrodcb@bchristopher;' +
        'PWD=KAPsig246!;' +
        'Encrypt=yes;' +
        'Connection Timeout=10;'
    )
    return database

# %%
cnxn = open_db_cnxn()

# %%
cursor = cnxn.cursor()

# %%
sql = (
    '''
    SELECT
        [Id],
		[GUID],
		CAST([CreatedDatetime] AS NVARCHAR(MAX)) AS CreatedDatetime,
        CAST([ModifiedDatetime] AS NVARCHAR(MAX)) AS ModifiedDatetime,
		[ClientId],
		[Tenant],
		[ClientSecret],
		[AccessToken],
		[ExpiresIn],
		[ExtExpiresIn],
		[RefreshToken],
		[Scope],
		[TokenType],
		[UserId]
	FROM ms.Auth;
    '''
)
sql
# Out:
# '\n    SELECT\n        [Id],\n\t\t[GUID],\n\t\tCAST([CreatedDatetime] AS NVARCHAR(MAX)) AS CreatedDatetime,\n        CAST([ModifiedDatetime] AS NVARCHAR(MAX)) AS ModifiedDatetime,\n\t\t[ClientId],\n\t\t[Tenant],\n\t\t[ClientSecret],\n\t\t[AccessToken],\n\t\t[ExpiresIn],\n\t\t[ExtExpiresIn],\n\t\t[RefreshToken],\n\t\t[Scope],\n\t\t[TokenType],\n\t\t[UserId]\n\tFROM ms.Auth;\n    '

# %%
row = cursor.execute(sql).fetchall()
row
# Out:
# [(1, '83BD22C6-BD97-4339-BBED-3C7179A2A8DF', '2025-05-31 15:55:46.6657810 +00:00', '2025-06-07 00:53:37.2393380 +00:00', '98a645bd-eed9-4f64-9839-05155706e1f6', '5daf13a1-5113-4d2c-bb43-13c6d113cf18', 'cGw8Q~60IAGKABQM3DnObRkT2kbdzLAWvM8albVt', 'eyJ0eXAiOiJKV1QiLCJub25jZSI6IlE0U3pQLVl4Wi0wNDZjUkVjQ2dLc291LS1WbHgwM0dsX25NUlU2Wnp6eW8iLCJhbGciOiJSUzI1NiIsIng1dCI6IkNOdjBPSTNSd3FsSEZFVm5hb01Bc2hDSDJYRSIsImtpZCI6IkNOdjBPSTNSd3FsSEZFVm5hb01Bc2hDSDJYRSJ9.....BuB0me6Pa2M2hkgPEmHekSE4wfJSjviAx2epgGP5erszXoo5rrJD3sSUbuAYcKx-k0ugKTRh9LeAWnzowswcYDg2oFKXaqjJBewXScMeyDLOMH3itDXgVHJmT6Im2RApGGqo_MXJCUqOsI1Dc2eOJB0x5GEH4hrKyYov2opWj-IXnhc0wEOLDDjR2YW8JTH27FZixTOrmW40IHNbSs2syslJd1EnKVyz1oVpM9aovffSfnWiyTcQITdJyrCxUniAqdutFiW8D_HgVFNzt766Pi6PYh15mw3MBOcMATNNplRDLZhp_n1-Nhw1lWfb4OCEJ9m7UlyIOVK96P8oZEpXIQ', 4870, 4870, '1.ATgAoROvXRNRLE27QxPG0RPPGL1FppjZ7mRPmDkFFVcG4fbNAeY4AA.AgABAwEAAABVrSpeuWamRam2jAF1XRQEAwDs_wUA9P8qQ3KeX2RFIYkQCTAzGgpOImlrkqidPtEuZT_hkaPVUxbh1I7zet63PXWstPbZl1vG2uboUlOnDVHV8ftePdcuJmXh_v6uzA2iAe5nFJxqq1i_c1bHJ37wermft7xMshFbv91sGeGbon0gOJ7QnNQ-TRTqDVs0NbjM7IrLYdHhbRhMVMq_LvA5d1-6z4sVtaT7uFr83DvHM6lCQxh_mnrvQryizi0DcbYNCvXE5424nrOooYlFRB1TcZ2eoPBpMPolt58CfIqfUO1LUobLx0sNJ9ZXlSZQeEB3kcZVNYOMTOjOD6YrGYL30uYQ5LzkxfxO01C4P-ww4mqWRFeRcP_Tj2zd7b5D9OMpKQNOWNCDJHBYrflmHsTRAPV2J17yc84C58UFgAfAvIfHJehQQOJ4DgRN4aYtqAyuZYwta9c8wkNJ7ygej-XQ0r8OshmPEWIQEVaA_E-DkULFwG6ZUKDnSQG0esaJENwNKkN_vPPFi5bcHJ9do0NkGAhsRERGC8pzjnLSekz-ep9XpLn4kNiGcXcUdBth64_NDOQ2bFcIM3XcMBHmdIMo19qSuhBQNQnYgQB74dNcUE6l2cducJ8uT2woh_1zGAo7v85Xw4kQVVGUvVUlC6_3cPVcKXpQJvnzysRa6gOEopWGfotcEIMm_slx9kRLw3Ze_6k-3xLMEkSky95qJ9XlVVc5aDnZKOpDRpDtG9BJa5w3jfutD6V_-lHqstuz6zr8K4kyD1J42AqpAieEDsyPd0QwzqqeWI1NBQTYfgm2gdGv-hONv6uCk69n77Cv8vg9AElTWHGo3UM-9YU6gPv9LApBKkliq78W5EbC_lej-kQMfPeShL6FY7WH8sgjkDBhoO7B0TaXdGniIpdU4F9Y1HWGB5IPf_qv3fKbc2xMd29H', 'Files.Read.All Files.ReadWrite.All Mail.Read Sites.Read.All Sites.Selected User.Read profile openid email', 'Bearer', 2)]

# %%
# Get column names from the cursor description
column_names = [desc[0] for desc in cursor.description]

# Loop through each tuple in row and print attribute name and value
for record in row:
    for name, value in zip(column_names, record):
        print(f"{name}: {value}")
    print("-" * 40)
# Out:
# Id: 1
# GUID: 83BD22C6-BD97-4339-BBED-3C7179A2A8DF
# CreatedDatetime: 2025-05-31 15:55:46.6657810 +00:00
# ModifiedDatetime: 2025-06-07 00:53:37.2393380 +00:00
# ClientId: 98a645bd-eed9-4f64-9839-05155706e1f6
# Tenant: 5daf13a1-5113-4d2c-bb43-13c6d113cf18
# ClientSecret: cGw8Q~60IAGKABQM3DnObRkT2kbdzLAWvM8albVt
# AccessToken: eyJ0eXAiOiJKV1QiLCJub25jZSI6IlE0U3pQLVl4Wi0wNDZjUkVjQ2dLc291LS1WbHgwM0dsX25NUlU2Wnp6eW8iLCJhbGciOiJSUzI1NiIsIng1dCI6IkNOdjBPSTNSd3FsSEZFVm5hb01Bc2hDSDJYRSIsImtpZCI6IkNOdjBPSTNSd3FsSEZFVm5hb01Bc2hDSDJYRSJ9.....BuB0me6Pa2M2hkgPEmHekSE4wfJSjviAx2epgGP5erszXoo5rrJD3sSUbuAYcKx-k0ugKTRh9LeAWnzowswcYDg2oFKXaqjJBewXScMeyDLOMH3itDXgVHJmT6Im2RApGGqo_MXJCUqOsI1Dc2eOJB0x5GEH4hrKyYov2opWj-IXnhc0wEOLDDjR2YW8JTH27FZixTOrmW40IHNbSs2syslJd1EnKVyz1oVpM9aovffSfnWiyTcQITdJyrCxUniAqdutFiW8D_HgVFNzt766Pi6PYh15mw3MBOcMATNNplRDLZhp_n1-Nhw1lWfb4OCEJ9m7UlyIOVK96P8oZEpXIQ
# ExpiresIn: 4870
# ExtExpiresIn: 4870
FFVcG4fbNAeY4AA.AgABAwEAAABVrSpeuWamRam2jAF1XRQEAwDs_wUA9P8qQ3KeX2RFIYkQCTAzGgpOImlrkqidPtEuZT_hkaPVUxbh1I7zet63PXWstPbZl1vG2uboUlOnDVHV8ftePdcuJmXh_v6uzA2iAe5nFJxqq1i_c1bHJ37wermft7xMshFbv91sGeGbon0gOJ7QnNQ-TRTqDVs0NbjM7IrLYdHhbRhMVMq_LvA5d1-6z4sVtaT7uFr83DvHM6lCQxh_mnrvQryizi0DcbYNCvXE5424nrOooYlFRB1TcZ2eoPBpMPolt58CfIqfUO1LUobLx0sNJ9ZXlSZQeEB3kcZVNYOMTOjOD6YrGYL30uYQ5LzkxfxO01C4P-ww4mqWRFeRcP_Tj2zd7b5D9OMpKQNOWNCDJHBYrflmHsTRAPV2J17yc84C58UFgAfAvIfHJehQQOJ4DgRN4aYtqAyuZYwta9c8wkNJ7ygej-XQ0r8OshmPEWIQEVaA_E-DkULFwG6ZUKDnSQG0esaJENwNKkN_vPPFi5bcHJ9do0NkGAhsRERGC8pzjnLSekz-ep9XpLn4kNiGcXcUdBth64_NDOQ2bFcIM3XcMBHmdIMo19qSuhBQNQnYgQB74dNcUE6l2cducJ8uT2woh_1zGAo7v85Xw4kQVVGUvVUlC6_3cPVcKXpQJvnzysRa6gOEopWGfotcEIMm_slx9kRLw3Ze_6k-3xLMEkSky95qJ9XlVVc5aDnZKOpDRpDtG9BJa5w3jfutD6V_-lHqstuz6zr8K4kyD1J42AqpAieEDsyPd0QwzqqeWI1NBQTYfgm2gdGv-hONv6uCk69n77Cv8vg9AElTWHGo3UM-9YU6gPv9LApBKkliq78W5EbC_lej-kQMfPeShL6FY7WH8sgjkDBhoO7B0TaXdGniIpdU4F9Y1HWGB5IPf_qv3fKbc2xMd29H', 'Files.Read.All Files.ReadWrite.All Mail.Read Sites.Read.All Sites.Selected User.Read profile openid email', 'Bearer', 2)

# %%
client_id = my_auth_record.__getattribute__('ClientId')
client_id
# Out:
# '98a645bd-eed9-4f64-9839-05155706e1f6'

# %%
tenant_id = my_auth_record.__getattribute__('Tenant')
tenant_id
# Out:
# '5daf13a1-5113-4d2c-bb43-13c6d113cf18'

# %%
client_secret = my_auth_record.__getattribute__('ClientSecret')
client_secret
# Out:
# 'cGw8Q~60IAGKABQM3DnObRkT2kbdzLAWvM8albVt'

# %%
access_token = my_auth_record.__getattribute__('AccessToken')
access_token
# Out:
# 'eyJ0eXAiOiJKV1QiLCJub25jZSI6IlE0U3pQLVl4Wi0wNDZjUkVjQ2dLc291LS1WbHgwM0dsX25NUlU2Wnp6eW8iLCJhbGciOiJSUzI1NiIsIng1dCI6IkNOdjBPSTNSd3FsSEZFVm5hb01Bc2hDSDJYRSIsImtpZCI6IkNOdjBPSTNSd3FsSEZFVm5hb01Bc2hDSDJYRSJ9.....BuB0me6Pa2M2hkgPEmHekSE4wfJSjviAx2epgGP5erszXoo5rrJD3sSUbuAYcKx-k0ugKTRh9LeAWnzowswcYDg2oFKXaqjJBewXScMeyDLOMH3itDXgVHJmT6Im2RApGGqo_MXJCUqOsI1Dc2eOJB0x5GEH4hrKyYov2opWj-IXnhc0wEOLDDjR2YW8JTH27FZixTOrmW40IHNbSs2syslJd1EnKVyz1oVpM9aovffSfnWiyTcQITdJyrCxUniAqdutFiW8D_HgVFNzt766Pi6PYh15mw3MBOcMATNNplRDLZhp_n1-Nhw1lWfb4OCEJ9m7UlyIOVK96P8oZEpXIQ'

# %%
https://imviokguifqdnyjvkb9idegwrhi.sharepoint.com/sites/RogersBuildLLC

# %%
headers = {
    'Authorization': f'Bearer {access_token}'
}
url = 'https://graph.microsoft.com/v1.0/sites/imviokguifqdnyjvkb9idegwrhi.sharepoint.com:/sites/RogersBuildLLC'
resp = requests.get(url=url, headers=headers, timeout=10)
resp.raise_for_status()  # Raise exception for bad status codes

# %%
print(
    json.dumps(
        resp.json(),
        indent=2
    )
)
# Out:
# {
#   "@odata.context": "https://graph.microsoft.com/v1.0/$metadata#sites/$entity",
#   "createdDateTime": "2019-06-06T13:40:18.78Z",
#   "description": "This will be our OneDrive shared library for all of the files that we all need to access.  OneDrive is part of Office365, so it will serve the same purpose as what Austin and I were previously using on our Google Drive.  The good thing about OneDrive is that the files can be synced with the OneDrive folder that will be configured on our new Dell XPS 15\" 2-in-1 laptops.",
#   "id": "imviokguifqdnyjvkb9idegwrhi.sharepoint.com,17981139-624e-48b0-b1ca-36a21ab8e963,1ae020ca-f72c-4665-98df-5a4a7b397436",
#   "lastModifiedDateTime": "2025-06-07T00:47:00Z",
#   "name": "RogersBuildLLC",
#   "webUrl": "https://imviokguifqdnyjvkb9idegwrhi.sharepoint.com/sites/RogersBuildLLC",
#   "displayName": "Rogers Build, Inc",
#   "root": {},
#   "siteCollection": {
#     "hostname": "imviokguifqdnyjvkb9idegwrhi.sharepoint.com"
#   }
# }

# %%
headers = {
    'Authorization': f'Bearer {access_token}'
}
url = 'https://graph.microsoft.com/v1.0/sites?search=Rogers*'
resp = requests.get(url=url, headers=headers, timeout=10)
resp.raise_for_status()  # Raise exception for bad status codes

# %%
print(
    json.dumps(
        resp.json(),
        indent=2
    )
)
# Out:
# {
#   "@odata.context": "https://graph.microsoft.com/v1.0/$metadata#sites",
#   "value": [
#     {
#       "createdDateTime": "2021-01-22T18:08:30Z",
#       "description": "Rogers Build Properties, LLC",
#       "id": "imviokguifqdnyjvkb9idegwrhi.sharepoint.com,9125b036-8258-4be9-bbb5-00b1a31785a1,e5e4a9d5-c8cb-495c-a22c-8a603e594485",
#       "lastModifiedDateTime": "2021-01-10T06:53:30Z",
#       "name": "RogersBuildPropertiesLLC",
#       "webUrl": "https://imviokguifqdnyjvkb9idegwrhi.sharepoint.com/sites/RogersBuildPropertiesLLC",
#       "displayName": "RBP, LLC",
#       "root": {},
#       "siteCollection": {
#         "hostname": "imviokguifqdnyjvkb9idegwrhi.sharepoint.com"
#       }
#     },
#     {
#       "createdDateTime": "2023-11-08T21:16:02Z",
#       "description": "The purpose of this site to test SharePoint",
#       "id": "imviokguifqdnyjvkb9idegwrhi.sharepoint.com,053b18f9-d2b8-4b5f-ac40-2e48acff2d4e,64e60bf3-24e5-4c1b-a264-d2b80665ce0e",
#       "lastModifiedDateTime": "2023-11-08T21:16:07Z",
#       "name": "testsite",
#       "webUrl": "https://imviokguifqdnyjvkb9idegwrhi.sharepoint.com/sites/testsite",
#       "displayName": "Test Site",
#       "root": {},
#       "siteCollection": {
#         "hostname": "imviokguifqdnyjvkb9idegwrhi.sharepoint.com"
#       }
#     }
#   ]
# }
