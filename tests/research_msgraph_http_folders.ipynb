# %%
import pyodbc

# %%
import requests

# %%
import json

# %%
def open_db_cnxn():
    """
    Opens a database connection.
    """
    database = pyodbc.connect(
        'DRIVER={ODBC Driver 17 for SQL Server};' +
        'SERVER=tcp:bchristopher.database.windows.net,1433;' +
        'DATABASE=buildone;' +
        'UID=zubrodcb@bchristopher;' +
        'PWD=KAPsig246!;' +
        'Encrypt=yes;' +
        'Connection Timeout=10;'
    )
    return database

# %%
cnxn = open_db_cnxn()

# %%
cursor = cnxn.cursor()

# %%
sql = (
    '''
    SELECT
        [Id],
		[GUID],
		CAST([CreatedDatetime] AS NVARCHAR(MAX)) AS CreatedDatetime,
        CAST([ModifiedDatetime] AS NVARCHAR(MAX)) AS ModifiedDatetime,
		[ClientId],
		[Tenant],
		[ClientSecret],
		[AccessToken],
		[ExpiresIn],
		[ExtExpiresIn],
		[RefreshToken],
		[Scope],
		[TokenType],
		[UserId]
	FROM ms.Auth;
    '''
)
sql
# Out:
# '\n    SELECT\n        [Id],\n\t\t[GUID],\n\t\tCAST([CreatedDatetime] AS NVARCHAR(MAX)) AS CreatedDatetime,\n        CAST([ModifiedDatetime] AS NVARCHAR(MAX)) AS ModifiedDatetime,\n\t\t[ClientId],\n\t\t[Tenant],\n\t\t[ClientSecret],\n\t\t[AccessToken],\n\t\t[ExpiresIn],\n\t\t[ExtExpiresIn],\n\t\t[RefreshToken],\n\t\t[Scope],\n\t\t[TokenType],\n\t\t[UserId]\n\tFROM ms.Auth;\n    '

# %%
row = cursor.execute(sql).fetchall()
row
# Out:
# [(1, '83BD22C6-BD97-4339-BBED-3C7179A2A8DF', '2025-05-31 15:55:46.6657810 +00:00', '2025-06-27 17:07:09.7526980 +00:00', '98a645bd-eed9-4f64-9839-05155706e1f6', '5daf13a1-5113-4d2c-bb43-13c6d113cf18', 'cGw8Q~60IAGKABQM3DnObRkT2kbdzLAWvM8albVt', 'eyJ0eXAiOiJKV1QiLCJub25jZSI6IlJMdV9QMnNRR0ZVWGlqejdWRHowSmkxZ28weXBJaUVXaEtnVmRtOHQ5aUkiLCJhbGciOiJSUzI1NiIsIng1dCI6Il9qTndqZVNudlRUSzhYRWRyNVFVUGtCUkxMbyIsImtpZCI6Il9qTndqZVNudlRUSzhYRWRyNVFVUGtCUkxMbyJ9.....gIOw_HBeIvMNfofVIb1oT7dfAQc6Y3YdAYeitAp8Q8L5rNE_ZvlNvzi31Yp8MAi07-Wl90943wGsBOxYlucmoV0iR-Q5k-xV8_Of_lccvgBMSd2N3DXmiw4dcYMN0VJWxu6mFJuIY2Pfyp4EUUDaLIoGGw9p2IvHAM4BhCiI4SR_IN3IUKvinsMn3IWuhBOChHLKTrXa6UEy55YT446uhOAgAkuQSxSTXo7vwykt6m1ZKmoTRFY1ccZ_W-9hDOqD5iskW69w5pPSD2EcjaFZzaCEaAwero5O3oILB892DzXQts7vmDoNXZU3bY4UjCAfcyoRzbZgN8MIfibIvubzYw', 4678, 4678, '1.ATgAoROvXRNRLE27QxPG0RPPGL1FppjZ7mRPmDkFFVcG4fbNAeY4AA.AgABAwEAAABVrSpeuWamRam2jAF1XRQEAwDs_wUA9P96HnDujOsHRzvff3I0iSWvAHBWQa1_gBTIbjwJpYi3mYIk0sqZ5INLXRtO7W4EijGmrXVFjJ5JaeTNJa8qRMZe
# ...

# %%
# Get column names from the cursor description
column_names = [desc[0] for desc in cursor.description]

# Loop through each tuple in row and print attribute name and value
for record in row:
    for name, value in zip(column_names, record):
        print(f"{name}: {value}")
    print("-" * 40)
# Out:
# Id: 1
# GUID: 83BD22C6-BD97-4339-BBED-3C7179A2A8DF
# CreatedDatetime: 2025-05-31 15:55:46.6657810 +00:00
# ModifiedDatetime: 2025-06-27 17:07:09.7526980 +00:00
# ClientId: 98a645bd-eed9-4f64-9839-05155706e1f6
# Tenant: 5daf13a1-5113-4d2c-bb43-13c6d113cf18
# ClientSecret: cGw8Q~60IAGKABQM3DnObRkT2kbdzLAWvM8albVt
# AccessToken: eyJ0eXAiOiJKV1QiLCJub25jZSI6IlJMdV9QMnNRR0ZVWGlqejdWRHowSmkxZ28weXBJaUVXaEtnVmRtOHQ5aUkiLCJhbGciOiJSUzI1NiIsIng1dCI6Il9qTndqZVNudlRUSzhYRWRyNVFVUGtCUkxMbyIsImtpZCI6Il9qTndqZVNudlRUSzhYRWRyNVFVUGtCUkxMbyJ9.....gIOw_HBeIvMNfofVIb1oT7dfAQc6Y3YdAYeitAp8Q8L5rNE_ZvlNvzi31Yp8MAi07-Wl90943wGsBOxYlucmoV0iR-Q5k-xV8_Of_lccvgBMSd2N3DXmiw4dcYMN0VJWxu6mFJuIY2Pfyp4EUUDaLIoGGw9p2IvHAM4BhCiI4SR_IN3IUKvinsMn3IWuhBOChHLKTrXa6UEy55YT446uhOAgAkuQSxSTXo7vwykt6m1ZKmoTRFY1ccZ_W-9hDOqD5iskW69w5pPSD2EcjaFZzaCEaAwero5O3oILB892DzXQts7vmDoNXZU3bY4UjCAfcyoRzbZgN8MIfibIvubzYw
# ExpiresIn: 4678
# ExtExpiresIn: 4678
# ...

# %%
my_auth_record = row[0]
my_auth_record
# Out:
# (1, '83BD22C6-BD97-4339-BBED-3C7179A2A8DF', '2025-05-31 15:55:46.6657810 +00:00', '2025-06-27 17:07:09.7526980 +00:00', '98a645bd-eed9-4f64-9839-05155706e1f6', '5daf13a1-5113-4d2c-bb43-13c6d113cf18', 'cGw8Q~60IAGKABQM3DnObRkT2kbdzLAWvM8albVt', 'eyJ0eXAiOiJKV1QiLCJub25jZSI6IlJMdV9QMnNRR0ZVWGlqejdWRHowSmkxZ28weXBJaUVXaEtnVmRtOHQ5aUkiLCJhbGciOiJSUzI1NiIsIng1dCI6Il9qTndqZVNudlRUSzhYRWRyNVFVUGtCUkxMbyIsImtpZCI6Il9qTndqZVNudlRUSzhYRWRyNVFVUGtCUkxMbyJ9.....gIOw_HBeIvMNfofVIb1oT7dfAQc6Y3YdAYeitAp8Q8L5rNE_ZvlNvzi31Yp8MAi07-Wl90943wGsBOxYlucmoV0iR-Q5k-xV8_Of_lccvgBMSd2N3DXmiw4dcYMN0VJWxu6mFJuIY2Pfyp4EUUDaLIoGGw9p2IvHAM4BhCiI4SR_IN3IUKvinsMn3IWuhBOChHLKTrXa6UEy55YT446uhOAgAkuQSxSTXo7vwykt6m1ZKmoTRFY1ccZ_W-9hDOqD5iskW69w5pPSD2EcjaFZzaCEaAwero5O3oILB892DzXQts7vmDoNXZU3bY4UjCAfcyoRzbZgN8MIfibIvubzYw', 4678, 4678, '1.ATgAoROvXRNRLE27QxPG0RPPGL1FppjZ7mRPmDkFFVcG4fbNAeY4AA.AgABAwEAAABVrSpeuWamRam2jAF1XRQEAwDs_wUA9P96HnDujOsHRzvff3I0iSWvAHBWQa1_gBTIbjwJpYi3mYIk0sqZ5INLXRtO7W4EijGmrXVFjJ5JaeTNJa8qRMZeQ
# ...

# %%
client_id = my_auth_record.__getattribute__('ClientId')
client_id
# Out:
# '98a645bd-eed9-4f64-9839-05155706e1f6'

# %%
tenant_id = my_auth_record.__getattribute__('Tenant')
tenant_id
# Out:
# '5daf13a1-5113-4d2c-bb43-13c6d113cf18'

# %%
client_secret = my_auth_record.__getattribute__('ClientSecret')
client_secret
# Out:
# 'cGw8Q~60IAGKABQM3DnObRkT2kbdzLAWvM8albVt'

# %%
access_token = my_auth_record.__getattribute__('AccessToken')
access_token
# Out:
# 'eyJ0eXAiOiJKV1QiLCJub25jZSI6IlJMdV9QMnNRR0ZVWGlqejdWRHowSmkxZ28weXBJaUVXaEtnVmRtOHQ5aUkiLCJhbGciOiJSUzI1NiIsIng1dCI6Il9qTndqZVNudlRUSzhYRWRyNVFVUGtCUkxMbyIsImtpZCI6Il9qTndqZVNudlRUSzhYRWRyNVFVUGtCUkxMbyJ9.....gIOw_HBeIvMNfofVIb1oT7dfAQc6Y3YdAYeitAp8Q8L5rNE_ZvlNvzi31Yp8MAi07-Wl90943wGsBOxYlucmoV0iR-Q5k-xV8_Of_lccvgBMSd2N3DXmiw4dcYMN0VJWxu6mFJuIY2Pfyp4EUUDaLIoGGw9p2IvHAM4BhCiI4SR_IN3IUKvinsMn3IWuhBOChHLKTrXa6UEy55YT446uhOAgAkuQSxSTXo7vwykt6m1ZKmoTRFY1ccZ_W-9hDOqD5iskW69w5pPSD2EcjaFZzaCEaAwero5O3oILB892DzXQts7vmDoNXZU3bY4UjCAfcyoRzbZgN8MIfibIvubzYw'

# %%
#https://imviokguifqdnyjvkb9idegwrhi.sharepoint.com/sites/RogersBuildLLC

# %%
headers = {
    'Authorization': f'Bearer {access_token}'
}
url = 'https://graph.microsoft.com/v1.0/sites/imviokguifqdnyjvkb9idegwrhi.sharepoint.com:/sites/RogersBuildLLC'
resp = requests.get(url=url, headers=headers, timeout=10)
resp.raise_for_status()  # Raise exception for bad status codes

# %%
resp_json = resp.json()
print(
    json.dumps(
        resp.json(),
        indent=2
    )
)
# Out:
# {
#   "@odata.context": "https://graph.microsoft.com/v1.0/$metadata#sites/$entity",
#   "createdDateTime": "2019-06-06T13:40:18.78Z",
#   "description": "This will be our OneDrive shared library for all of the files that we all need to access.  OneDrive is part of Office365, so it will serve the same purpose as what Austin and I were previously using on our Google Drive.  The good thing about OneDrive is that the files can be synced with the OneDrive folder that will be configured on our new Dell XPS 15\" 2-in-1 laptops.",
#   "id": "imviokguifqdnyjvkb9idegwrhi.sharepoint.com,17981139-624e-48b0-b1ca-36a21ab8e963,1ae020ca-f72c-4665-98df-5a4a7b397436",
#   "lastModifiedDateTime": "2025-06-27T20:00:01Z",
#   "name": "RogersBuildLLC",
#   "webUrl": "https://imviokguifqdnyjvkb9idegwrhi.sharepoint.com/sites/RogersBuildLLC",
#   "displayName": "Rogers Build, Inc",
#   "root": {},
#   "siteCollection": {
#     "hostname": "imviokguifqdnyjvkb9idegwrhi.sharepoint.com"
#   }
# }

# %%
resp_code = None
if resp_json.get('error'):
    print(f"Error: {resp_json['error']['message']}")
    resp_code = resp_json['error']['code']
else:
    print("Request was successful.")
    resp_code = resp_json.get('id')
# Out:
# Request was successful.

# %%
headers = {
    'Authorization': f'Bearer {access_token}'
}
url = 'https://graph.microsoft.com/v1.0/sites/imviokguifqdnyjvkb9idegwrhi.sharepoint.com,17981139-624e-48b0-b1ca-36a21ab8e963,1ae020ca-f72c-4665-98df-5a4a7b397436/drives'
resp = requests.get(url=url, headers=headers, timeout=10)
resp.raise_for_status()  # Raise exception for bad status codes

# %%
resp_json = resp.json()
print(
    json.dumps(
        resp.json(),
        indent=2
    )
)
# Out:
# {
#   "@odata.context": "https://graph.microsoft.com/v1.0/$metadata#drives",
#   "value": [
#     {
#       "createdDateTime": "2019-06-20T16:42:01Z",
#       "description": "sharepoint list",
#       "id": "b!ORGYF05isEixyjaiGrjpY8og4Bos92VGmN9aSns5dDZKYXGC5U9ERZ0GWoE834yz",
#       "lastModifiedDateTime": "2021-10-02T01:58:37Z",
#       "name": "Teams Wiki Data",
#       "webUrl": "https://imviokguifqdnyjvkb9idegwrhi.sharepoint.com/sites/RogersBuildLLC/Teams%20Wiki%20Data",
#       "driveType": "documentLibrary",
#       "createdBy": {
#         "user": {
#           "email": "austin.2@rogersbuild.com",
#           "id": "b3ecf426-9e19-423b-a6ce-9072d3d0f8aa",
#           "displayName": "Austin Rogers"
#         }
#       },
#       "lastModifiedBy": {
#         "user": {
#           "displayName": "System Account"
#         }
#       },
#       "owner": {
#         "group": {
#           "email": "RogersBuildLLC@imVioKGuiFqdNYjvKB9idEgwrHI.onmicrosoft.com",
# ...

# %%
headers = {
    'Authorization': f'Bearer {access_token}'
}
url = 'https://graph.microsoft.com/v1.0/drives/b!ORGYF05isEixyjaiGrjpY8og4Bos92VGmN9aSns5dDZlsBbazGm1R72YjQfn3bmj/root/delta'
resp = requests.get(url=url, headers=headers, timeout=10)
resp.raise_for_status()  # Raise exception for bad status codes

# %%
resp_json = resp.json()
print(
    json.dumps(
        resp.json(),
        indent=2
    )
)
# Out:
# {
#   "@odata.context": "https://graph.microsoft.com/v1.0/$metadata#Collection(driveItem)",
#   "@odata.nextLink": "https://graph.microsoft.com/v1.0/drives/b!ORGYF05isEixyjaiGrjpY8og4Bos92VGmN9aSns5dDZlsBbazGm1R72YjQfn3bmj/root/delta?token=NDslMjMzOyUyMzE7MztkYTE2YjA2NS02OWNjLTQ3YjUtYmQ5OC04ZDA3ZTdkZGI5YTM7NjM4ODY2NTg5OTgyMTMwMDAwOzEyNzk4MjA3NTE7JTIzUGFnZWQ9VFJVRSUyNnBfSUQ9MzQ0JTI2aXhfUGFnZWQ9VFJVRSUyNml4X0lEPTM0NCUyNml4X0tleT1FOERERkQ2NjU0REE0NTA1QURFNEVEQUVDRjI2MzFEQTslMjM7JTIzMDslMjM",
#   "value": [
#     {
#       "@odata.type": "#microsoft.graph.driveItem",
#       "createdDateTime": "2019-06-05T02:16:09Z",
#       "id": "017ZKYN556Y2GOVW7725BZO354PWSELRRZ",
#       "lastModifiedDateTime": "2025-06-27T20:00:01Z",
#       "name": "root",
#       "parentReference": {
#         "driveType": "documentLibrary",
#         "driveId": "b!ORGYF05isEixyjaiGrjpY8og4Bos92VGmN9aSns5dDZlsBbazGm1R72YjQfn3bmj"
#       },
# ...

# %%
headers = {
    'Authorization': f'Bearer {access_token}'
}
url = 'https://graph.microsoft.com/v1.0/sites/imviokguifqdnyjvkb9idegwrhi.sharepoint.com,17981139-624e-48b0-b1ca-36a21ab8e963,1ae020ca-f72c-4665-98df-5a4a7b397436/drive/items/017ZKYN52NGVPCXKVI3ZG2IOZUIEYMJN7W/children'
resp = requests.get(url=url, headers=headers, timeout=10)
resp.raise_for_status()  # Raise exception for bad status codes

# %%
resp_json = resp.json()
print(
    json.dumps(
        resp.json(),
        indent=2
    )
)
# Out:
# {
#   "@odata.context": "https://graph.microsoft.com/v1.0/$metadata#Collection(driveItem)",
#   "@odata.nextLink": "https://graph.microsoft.com/v1.0/sites/imviokguifqdnyjvkb9idegwrhi.sharepoint.com,17981139-624e-48b0-b1ca-36a21ab8e963,1ae020ca-f72c-4665-98df-5a4a7b397436/drive/items/017ZKYN52NGVPCXKVI3ZG2IOZUIEYMJN7W/children?$skiptoken=UGFnZWQ9VFJVRSZwX1NvcnRCZWhhdmlvcj0wJnBfRmlsZUxlYWZSZWY9VEIzKy0rV2Fsa2VyK0x1bWJlcistKzAxOTg0NistK0x1bWJlcislMjYrSGFyZHdhcmUrLSsxMy4xKy0rJTI0MzA1LjAwKy0rNC04LTIwMjUucGRmJnBfSUQ9MTI0OTA2",
#   "value": [
#     {
# ...
